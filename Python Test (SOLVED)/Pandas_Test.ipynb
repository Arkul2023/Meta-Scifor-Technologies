# %%
## Q1
## Using the below function the dictionary is converted to Dataframe
import pandas as pd

data = {'Name': ['Alice', 'Bob', 'Charlie'], 'Age': [25, 30, 35], 'City': ['New York', 'Paris', 'London']}
df = pd.DataFrame(data)

df
# Out:
#       Name  Age      City
# 0    Alice   25  New York
# 1      Bob   30     Paris
# 2  Charlie   35    London

# %%
## Q2

df = pd.read_csv("https://raw.githubusercontent.com/Arkul2023/Meta-Scifor-Technologies/refs/heads/main/Datasets/Book1.csv")
df
# Out:
#    Overs  Runs
# 0      1    45
# 1      2    34
# 2      3    67
# 3      4    12
# 4      5    23
# 5      6    89
# 6      7    65
# 7      8    23
# 8      9    76
# 9     10    87

# %%
## Q3

df = pd.read_csv("https://raw.githubusercontent.com/Arkul2023/Meta-Scifor-Technologies/refs/heads/main/Datasets/eda_data.csv")

df.head(10)          ## Displays only 1st 10 rows of the dataset as shown below
# Out:
#    Unnamed: 0                  Job Title               Salary Estimate  \
# 0           0             Data Scientist    $53K-$91K (Glassdoor est.)
# 1           1  Healthcare Data Scientist   $63K-$112K (Glassdoor est.)
# 2           2             Data Scientist    $80K-$90K (Glassdoor est.)
# 3           3             Data Scientist    $56K-$97K (Glassdoor est.)
# 4           4             Data Scientist   $86K-$143K (Glassdoor est.)
# 5           5             Data Scientist   $71K-$119K (Glassdoor est.)
# 6           6             Data Scientist    $54K-$93K (Glassdoor est.)
# 7           7             Data Scientist   $86K-$142K (Glassdoor est.)
# 8           8         Research Scientist    $38K-$84K (Glassdoor est.)
# 9           9             Data Scientist  $120K-$160K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# ...

# %%
## Q4

dict = {'Name': ['Alice', 'Bob', 'Charlie'], 'Age': [25, 30, 35], 'City': ['New York', 'Paris', 'London']}
df = pd.DataFrame(dict)

selected_columns = df[['Name', 'Age']]   ## Selects specific columns in dataframe
print(selected_columns)
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35

# %%
## Q5

df = pd.read_csv("https://raw.githubusercontent.com/Arkul2023/Meta-Scifor-Technologies/refs/heads/main/Datasets/eda_data.csv")
df.shape
# Out:
# (742, 33)

# %%
## Q6

df = pd.read_csv("https://raw.githubusercontent.com/Arkul2023/Meta-Scifor-Technologies/refs/heads/main/Datasets/eda_data.csv")
df.isnull().sum()
# Out:
# Unnamed: 0           0
# Job Title            0
# Salary Estimate      0
# Job Description      0
# Rating               0
# Company Name         0
# Location             0
# Headquarters         0
# Size                 0
# Founded              0
# Type of ownership    0
# Industry             0
# Sector               0
# Revenue              0
# Competitors          0
# hourly               0
# employer_provided    0
# min_salary           0
# max_salary           0
# avg_salary           0
# company_txt          0
# job_state            0
# same_state           0
# age                  0
# python_yn            0
# R_yn                 0
# spark                0
# aws                  0
# excel                0
# job_simp             0
# seniority            0
# desc_len             0
# num_comp             0
# dtype: int64

# %%
## Q7

dict = {'Name': ['Alice', 'Bob', 'Charlie'], 'Age': [25, 30, 35], 'City': ['New York', 'Paris', 'London']}
df = pd.DataFrame(dict)

df['Country'] = 'USA'       ## Adds a new column in dataframe
df
# Out:
#       Name  Age      City Country
# 0    Alice   25  New York     USA
# 1      Bob   30     Paris     USA
# 2  Charlie   35    London     USA

# %%
## Q8

dict = {'Name': ['Alice', 'Bob', 'Charlie'], 'Age': [25, 30, 35], 'City': ['New York', 'Paris', 'London']}
df = pd.DataFrame(dict)

del df['City']      ## Deletes Column from the dataset

df
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35

# %%
## Q9

dict = {'Name': ['Alice', 'Bob', 'Charlie'], 'Age': [25, 30, 35], 'City': ['New York', 'Paris', 'London']}
df = pd.DataFrame(dict)

df = df.rename(columns={'Age': 'Years'})
print(df)    ## Changes the name of the columns
# Out:
#       Name  Years      City
# 0    Alice     25  New York
# 1      Bob     30     Paris
# 2  Charlie     35    London

# %% [markdown]
# ## Intermediate Level

# %%
## Q11

dict = {'Name': ['Alice', 'Bob', 'Charlie'], 'Age': [25, 30, 35], 'City': ['New York', 'Paris', 'London']}
df = pd.DataFrame(dict)

filter_age = df[df['Age']>30]    ## prints the data where ages are greater than 30
filter_age
# Out:
#       Name  Age    City
# 2  Charlie   35  London

# %%
## Q12

dict = {'Name': ['Alice', 'Bob', 'Charlie'], 'Age': [25, 30, 35], 'City': ['New York', 'Paris', 'London']}
df = pd.DataFrame(dict)

df['Age_Group'] = df['Age'].apply(lambda x: 'Young' if x <= 30 else 'Old')    ## Creates new column where the condition inside lambda is applied

df
# Out:
#       Name  Age      City Age_Group
# 0    Alice   25  New York     Young
# 1      Bob   30     Paris     Young
# 2  Charlie   35    London       Old

# %%
## Q15

dict = {'Name': ['Alice', 'Bob', 'Charlie'], 'Age': [25, 30, 35], 'City': ['New York', 'Paris', 'Paris']}
df = pd.DataFrame(dict)

df['City'].unique()                          ## Prints unique values in column
# Out:
# array(['New York', 'Paris'], dtype=object)

# %%
## Q16

dict = {'Name': ['Alice', 'Bob', 'Charlie'], 'Age': [25, 30, 35], 'City': ['New York', 'Paris', 'Paris']}
df = pd.DataFrame(dict)

city_counts = df['City'].value_counts()         ## Counts number of cities
city_counts
# Out:
# City
# Paris       2
# New York    1
# Name: count, dtype: int64

# %%
## Q18

import pandas as pd

df1 = pd.DataFrame({'ID': [1, 2, 3],'Name': ['Mahesh', 'Arvind', 'Vaibhav']})
df2 = pd.DataFrame({'ID': [2, 3, 4],'Score': [58, 94, 77]})

merge = pd.merge(df1, df2, on='ID')              ## Merges two data frames with common ID as mentioned in the question
merge
# Out:
#    ID     Name  Score
# 0   2   Arvind     58
# 1   3  Vaibhav     94

# %%
## Q20

import pandas as pd
import numpy as np

df = pd.DataFrame({'Name':['Arvind','Vinay',np.nan], 'Age':[23,34,np.nan],'ID':[1, np.nan, 9]})

df = df.dropna()        ## Drops data containg null values
df
# Out:
#      Name   Age   ID
# 0  Arvind  23.0  1.0

# %%
## Q17

import pandas as pd

df1 = pd.DataFrame({'ID': [1, 2, 3],'Name': ['Mahesh', 'Arvind', 'Vaibhav']})
df2 = pd.DataFrame({'ID': [4, 5, 6],'Name': ['Nany','Sumit','Arjun']})

df = pd.concat([df1, df2], axis=0, ignore_index=True)     ## Concatenates row wise ignoring the indexes
df
# Out:
#    ID     Name
# 0   1   Mahesh
# 1   2   Arvind
# 2   3  Vaibhav
# 3   4     Nany
# 4   5    Sumit
# 5   6    Arjun

# %% [markdown]
# ## Advanced Section

# %%
## Q21

import pandas as pd

# Example DataFrame with date as string
data = {'date': ['2023-01-01', '2023-02-01', '2023-03-01']}
df = pd.DataFrame(data)

# Convert the 'date' column to pandas datetime objects
df['date'] = pd.to_datetime(df['date'])

print(df)
# Out:
#         date
# 0 2023-01-01
# 1 2023-02-01
# 2 2023-03-01

# %%
## Q22

date_range=pd.date_range('11/05/1989',periods=8)        ## writing the range first from we want dates
dates=pd.DataFrame(date_range,columns=['Date'])

dates['year']=dates['Date'].dt.year                      ## Taking Date, Time , and year separate columns
dates['month']=dates['Date'].dt.month
dates['day']=dates['Date'].dt.day

dates
# Out:
#         Date  year  month  day
# 0 1989-11-05  1989     11    5
# 1 1989-11-06  1989     11    6
# 2 1989-11-07  1989     11    7
# 3 1989-11-08  1989     11    8
# 4 1989-11-09  1989     11    9
# 5 1989-11-10  1989     11   10
# 6 1989-11-11  1989     11   11
# 7 1989-11-12  1989     11   12

# %%
## Q24

import pandas as pd

# Create a DataFrame
data = {'start_date': ['2024-01-01', '2024-05-01', '2024-11-15'],
        'end_date': ['2024-01-10', '2024-05-15', '2024-11-25']}

df = pd.DataFrame(data)
df['start_date'] = pd.to_datetime(df['start_date'])
df['end_date'] = pd.to_datetime(df['end_date'])

# Calculate the time difference in days
df['days_difference'] = (df['end_date'] - df['start_date']).dt.days

print(df)
# Out:
#   start_date   end_date  days_difference
# 0 2024-01-01 2024-01-10                9
# 1 2024-05-01 2024-05-15               14
# 2 2024-11-15 2024-11-25               10

# %%
## Q25

import pandas as pd

# Example DataFrame
data = {'date': ['2021-05-01', '2022-03-15', '2022-07-20', '2023-01-10'],
        'sales': [100, 200, 150, 250]}

df = pd.DataFrame(data)
df['date'] = pd.to_datetime(df['date'])

# Extract the year from the date column
df['year'] = df['date'].dt.year

# Group by the year and calculate the total sales for each year
grouped = df.groupby('year')['sales'].sum().reset_index()

print(grouped)
# Out:
#    year  sales
# 0  2021    100
# 1  2022    350
# 2  2023    250

# %%
## Q26

data = {'date': ['2021-05-01', '2022-03-15', '2022-07-20', '2023-01-10'],
        'sales': [100, 200, 150, 250]}

df['sales'].mean()                              ## Calculates mean of the sales column
# Out:
# 175.0

# %%
## Q27

import pandas as pd

# Create a DataFrame
data = {'region': ['Russia', 'India', 'Russia', 'India', 'Russia'],'category': ['A', 'B', 'A', 'B', 'A'],
        'sales': [100, 200, 150, 250, 300]}

df = pd.DataFrame(data)

# Group by 'region' and 'category' and calculate the sum of sales
grouped = df.groupby(['region', 'category'])['sales'].sum()

print(grouped)
# Out:
# region  category
# India   B           450
# Russia  A           550
# Name: sales, dtype: int64

# %%
## Q28

import pandas as pd

# Create a DataFrame
data = {'region': ['North', 'South', 'East', 'West'],'sales': [1000, 2000, 9500, 8000]}

df = pd.DataFrame(data)

# Group by 'region' and calculate the total sales
grouped = df.groupby('region')['sales'].sum()

# Filter groups where total sales are greater than 5000
filtered_groups = grouped[grouped > 5000]

print(filtered_groups)
# Out:
# region
# East    9500
# West    8000
# Name: sales, dtype: int64

# %%
##Q32

import pandas as pd

df = pd.DataFrame({'name': ['Aryan', 'Ganesh', 'Chetan'],'age': [25, 30, 35]})

# Select all rows and 2 columns
subset = df.iloc[:2]

print(subset)
# Out:
#      name  age
# 0   Aryan   25
# 1  Ganesh   30

# %%
## Q34

import pandas as pd

df = pd.DataFrame({'name': ['Aryan', 'Ganesh', 'Chetan'],'age': [25, 30, 35]})

# Reverse the rows using .iloc[]
reversed_df = df.iloc[::-1].reset_index(drop=True)

print(reversed_df)
# Out:
#      name  age
# 0  Chetan   35
# 1  Ganesh   30
# 2   Aryan   25
